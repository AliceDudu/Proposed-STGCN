# %%
import numpy as np
adj = np.load('./data/metr-la/adj.npz')
adj['format']
# Out:
# array(b'csc', dtype='|S3')

# %%
adj['data'].shape
# Out:
# (22167,)

# %%
import pandas as pd
data = pd.read_csv('./data/metr-la/vel.csv')
data
# Out:
#           64.375     67.625     67.125       61.5     66.875      68.75  \
# 0      62.666667  68.555556  65.444444  62.444444  64.444444  68.111111
# 1      64.000000  63.750000  60.000000  59.000000  66.500000  66.250000
# 2       0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4      57.333333  69.000000  67.666667  61.666667  67.333333  69.000000
# ...          ...        ...        ...        ...        ...        ...
# 34266  65.000000  65.888889  68.555556  61.666667   0.000000  54.555556
# 34267  61.375000  65.625000  66.500000  62.750000   0.000000  50.500000
# 34268  67.000000  59.666667  69.555556  61.000000   0.000000  44.777778
# 34269  66.750000  62.250000  66.000000  59.625000   0.000000  53.000000
# 34270  65.111111  66.888889  66.777778  61.222222   0.000000  49.555556
#
#           65.125   67.125.1     59.625      62.75  ...     45.625     65.5.2  \
# ...

# %%
import scipy.sparse as sp 

adj = sp.load_npz('./data/metr-la/adj.npz')
adj = adj.tocsc()
adj
# Out:
# <207x207 sparse matrix of type '<class 'numpy.float64'>'
# 	with 22167 stored elements in Compressed Sparse Column format>
